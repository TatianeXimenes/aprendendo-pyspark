# %%
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark.sql import Window
import pandas as pd

# %% [markdown]
# ### Leitura de dados

# %%
read_path = '/home/tatiane/Downloads/exemplo_linkage_cases-brazil-cities-time.csv/tmp/exemplo_linkage_cases-brazil-cities-time.csv'

# %%
df = spark.read.csv(read_path, sep = ",", multiLine = True)

# %%
#renomeando colunas
header = ["id1", "id2", "city1", "city2", "regiao_saude1", "regiao_saude2", "codmun1", "codmun2", "date1", "date2", "epi_week1", "epi_week2", "score"]

for nome_antigo, novo_nome in zip(df.columns, header):
    df = df.withColumnRenamed(nome_antigo, novo_nome)

# %%
df.printSchema()
# Out:
# root
#  |-- id1: string (nullable = true)
#  |-- id2: string (nullable = true)
#  |-- city1: string (nullable = true)
#  |-- city2: string (nullable = true)
#  |-- regiao_saude1: string (nullable = true)
#  |-- regiao_saude2: string (nullable = true)
#  |-- codmun1: string (nullable = true)
#  |-- codmun2: string (nullable = true)
#  |-- date1: string (nullable = true)
#  |-- date2: string (nullable = true)
#  |-- epi_week1: string (nullable = true)
#  |-- epi_week2: string (nullable = true)
#  |-- score: string (nullable = true)

# %% [markdown]
# ### Filtrando dados

# %%
df.limit(5).toPandas()
# Out:
#   id1 id2         city1         city2 regiao_saude1 regiao_saude2 codmun1  \
# 0   0   0  São Paulo/SP  São Paulo/SP     São Paulo     São Paulo  355030
# 1   2   2  São Paulo/SP  São Paulo/SP     São Paulo     São Paulo  355030
# 2   4   4  São Paulo/SP  São Paulo/SP     São Paulo     São Paulo  355030
# 3   6   6  São Paulo/SP  São Paulo/SP     São Paulo     São Paulo  355030
# 4   1   1         TOTAL         TOTAL          None          None       0
#
#   codmun2     date1     date2 epi_week1 epi_week2               score
# 0  355030  20200225  20200225         9         9                 1.0
# 1  355030  20200226  20200226         9         9                 1.0
# 2  355030  20200227  20200227         9         9                 1.0
# 3  355030  20200228  20200228         9         9                 1.0
# 4       0  20200225  20200225         9         9  0.7237569060773481

# %%
#df = df.sample(0.25).cache()

# %%
df = df.limit(100).cache()

# %%
# Converter o tipo correto
df = df.withColumn('score', F.col('score').cast(DoubleType()))

# %%
#df.summary().toPandas()
df.summary().toPandas().set_index('summary').T #transforma coluna em linhas para facilitar a visão da tabela.
# Out:
# summary       count                mean               stddev  \
# id1             100              206.45   126.29397923859709
# id2             100              206.45   126.29397923859709
# city1           100                None                 None
# city2           100                None                 None
# regiao_saude1    87                None                 None
# regiao_saude2    87            130260.0                  0.0
# codmun1         100            309669.5   146732.67238575278
# codmun2         100           711070.61   2801930.1665854403
# date1           100       2.020031101E7   17.688948210826418
# date2           100       1.979630494E7    2842289.001004823
# epi_week1       100               11.41   0.7925792188682583
# epi_week2       100               11.19    1.661780717036743
# score            98  0.9633555079490359  0.09418324801510738
#
# summary                            min          25%          50%          75%  \
# id1                                  0        100.0        198.0        322.0
# id2                                  0        100.0        198.0        322.0
# city1          Aparecida de Goiânia/GO         None         None         None
# city2          Aparecida de Goiânia/GO         None         None         None
# regiao_saude1          "Manaus,"Manaus         None         None         None
# regiao_saude2                   130260     130260.0     130260.0     130260.0
# codmun1                              0     260790.0     330040.0     411370.0
# codmun2                              0     270430.0     330040.0     411915.0
# date1                         20200225  2.0200312E7  2.0200315E7  2.0200318E7
# date2                               12  2.0200312E7  2.0200315E7  2.0200318E7
# epi_week1                           10         11.0         12.0         12.0
# epi_week2                          1.0         11.0         12.0         12.0
# score               0.7237569060773481          1.0          1.0          1.0
#
# summary              max
# id1                   99
# id2                   99
# city1              TOTAL
# city2              TOTAL
# regiao_saude1  São Paulo
# regiao_saude2  São Paulo
# codmun1           530010
# codmun2           530010
# date1           20200319
# date2           20200319
# epi_week1              9
# epi_week2              9
# score                1.0

# %% [markdown]
# ### Extraindo dados de colunas
# * Dia, mes, ano
# * Extraindo o estado do municipio

# %% [markdown]
# ### Operações entre colunas
# * +, -, *, /

# %% [markdown]
# ### Comparando colunas
# * Colunas de linkage
# * Registros com score igual a 1
